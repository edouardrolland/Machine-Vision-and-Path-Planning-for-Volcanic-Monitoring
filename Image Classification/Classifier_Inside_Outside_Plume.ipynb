# %%
# !nvidia-smi
# Out:
# Fri Jun 23 12:40:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# # Install YOLOv8

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.121 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 24.1/166.8 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %% [markdown]
# #Import dataset

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="Enter Your ROBOFLOW API HERE")
project = rf.workspace("university-of-bristol-v8lxj").project("inside-plume-classifier")
dataset = project.version(2).download("folder")
# Out:
# /content/datasets
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.3 MB/s eta 0:00:00
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Inside-Plume-Classifier-2 in folder:: 100%|██████████| 1472/1472 [00:00<00:00, 4865.61it/s]

# %%
# %cd {HOME}

# !yolo task=classify mode=train model=yolov8n-cls.pt data={dataset.location} epochs=100 imgsz=640
# Out:
# /content
# ...
# 100% 5.28M/5.28M [00:00<00:00, 80.9MB/s]
# Ultralytics YOLOv8.0.121 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# ...

# %%
# %cd {HOME}

# !yolo task=classify mode=val model={HOME}/runs/classify/train/weights/best.pt data={dataset.location}
# Out:
# /content
# Ultralytics YOLOv8.0.121 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla V100-SXM2-16GB, 16151MiB)
# YOLOv8n-cls summary (fused): 73 layers, 1437442 parameters, 0 gradients
# WARNING ⚠️ Dataset 'split=val' not found, using 'split=test' instead.
#                classes   top1_acc   top5_acc: 100% 1/1 [00:00<00:00, 13.34it/s]
#                    all          1          1
# Speed: 0.5ms preprocess, 7.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val

# %%
# !ls /content/runs

# !zip -r /content/runs.zip /content/runs
# Out:
# classify
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/classify/ (stored 0%)
#   adding: content/runs/classify/train/ (stored 0%)
#   adding: content/runs/classify/train/train_batch1.jpg (deflated 9%)
#   adding: content/runs/classify/train/val_batch0_labels.jpg (deflated 11%)
#   adding: content/runs/classify/train/results.png (deflated 14%)
#   adding: content/runs/classify/train/weights/ (stored 0%)
#   adding: content/runs/classify/train/weights/best.pt (deflated 9%)
#   adding: content/runs/classify/train/weights/last.pt (deflated 9%)
#   adding: content/runs/classify/train/val_batch0_pred.jpg (deflated 11%)
#   adding: content/runs/classify/train/train_batch2.jpg (deflated 9%)
#   adding: content/runs/classify/train/events.out.tfevents.1687525668.2772cc36ddbe.10978.0 (deflated 72%)
#   adding: content/runs/classify/train/train_batch0.jpg (deflated 5%)
#   adding: content/runs/classify/train/confusion_matrix_normalized.png (deflated 36%)
# ...

# %%
from google.colab import files

files.download('/content/runs.zip')
